# %%
import pandas as pd
df = pd.read_csv('datasets/gapminder.tsv', sep='\t')

# %%
len(df)
# Out:
# 1704

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
df['pop']
# Out:
# 0        8425333
# 1        9240934
# 2       10267083
# 3       11537966
# 4       13079460
#           ...
# 1699     9216418
# 1700    10704340
# 1701    11404948
# 1702    11926563
# 1703    12311143
# Name: pop, Length: 1704, dtype: int64

# %%
df[['country','pop']].head(3)
# Out:
#        country       pop
# 0  Afghanistan   8425333
# 1  Afghanistan   9240934
# 2  Afghanistan  10267083

# %%
df[['continent', 'pop']].tail(7)
# Out:
#      continent       pop
# 1697    Africa   6642107
# 1698    Africa   7636524
# 1699    Africa   9216418
# 1700    Africa  10704340
# 1701    Africa  11404948
# 1702    Africa  11926563
# 1703    Africa  12311143

# %%
df['pop'][2]
# Out:
# 10267083

# %%
df.iloc[-1]
# Out:
# country      Zimbabwe
# continent      Africa
# year             2007
# lifeExp        43.487
# pop          12311143
# gdpPercap     469.709
# Name: 1703, dtype: object

# %%
df.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\range.py:355, in RangeIndex.get_loc(self, key, method, tolerance)
#     354 try:
# --> 355     return self._range.index(new_key)
#     356 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [25], line 1
# ----> 1 df.loc[-1]
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:879, in _LocationIndexer.__getitem__(self, key)
#     876 axis = self.axis or 0
#     878 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
df2 = pd.DataFrame({'price': [3.50, 2.68, 1.41, 9.90, 18.21],
                   'msrp': [4.99, 3.99, 1.99, 19.99, 29.99]},
                  index=['apple', 'milk', 'bread', 'beer', 'diaper'])
df2
# Out:
#         price   msrp
# apple    3.50   4.99
# milk     2.68   3.99
# bread    1.41   1.99
# beer     9.90  19.99
# diaper  18.21  29.99

# %%
df2.iloc[1:5:2]
# Out:
#       price   msrp
# milk   2.68   3.99
# beer   9.90  19.99

# %%
df2.loc['milk']
# Out:
# price    2.68
# msrp     3.99
# Name: milk, dtype: float64

# %%
df.iloc[1::100]
# Out:
#                     country continent  year  lifeExp        pop     gdpPercap
# 1               Afghanistan      Asia  1957   30.332    9240934    820.853030
# 101              Bangladesh      Asia  1977   46.923   80428306    659.877232
# 201            Burkina Faso    Africa  1997   50.324   10352843    946.294962
# 301                Colombia  Americas  1957   55.118   14485993   2323.805581
# 401          Czech Republic    Europe  1977   70.710   10161915  14800.160620
# 501                 Eritrea    Africa  1997   53.378    4058319    913.470790
# 601               Guatemala  Americas  1957   44.142    3640876   2617.155967
# 701                   India      Asia  1977   54.208  634000000    813.337323
# 801                   Japan      Asia  1997   80.690  125956499  28816.584990
# 901                   Libya    Africa  1957   45.289    1201578   3448.284395
# 1001               Mongolia      Asia  1977   55.491    1528000   1647.511665
# ...

# %%
for i in df2.index:
    print(df2.loc[i])
# Out:
# price    3.50
# msrp     4.99
# Name: apple, dtype: float64
# price    2.68
# msrp     3.99
# Name: milk, dtype: float64
# price    1.41
# msrp     1.99
# Name: bread, dtype: float64
# price     9.90
# msrp     19.99
# Name: beer, dtype: float64
# price    18.21
# msrp     29.99
# Name: diaper, dtype: float64

# %%
df.loc[1:5, ['year', 'pop']]
# Out:
#    year       pop
# 1  1957   9240934
# 2  1962  10267083
# 3  1967  11537966
# 4  1972  13079460
# 5  1977  14880372

# %%
df.iloc[1:5, [0,1,2]]
# Out:
#        country continent  year
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
df.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df.groupby(['continent','year'])[['lifeExp','pop']].mean()
#round(df.groupby(['continent','year'])[['lifeExp','pop']].mean())
# Out:
#                 lifeExp          pop
# continent year
# Africa    1952     39.0    4570010.0
#           1957     41.0    5093033.0
#           1962     43.0    5702247.0
#           1967     45.0    6447875.0
#           1972     47.0    7305376.0
#           1977     50.0    8328097.0
#           1982     52.0    9602857.0
#           1987     53.0   11054502.0
#           1992     54.0   12674645.0
#           1997     54.0   14304480.0
#           2002     53.0   16033152.0
#           2007     55.0   17875763.0
# Americas  1952     53.0   13806098.0
#           1957     56.0   15478157.0
#           1962     58.0   17330810.0
#           1967     60.0   19229865.0
#           1972     62.0   21175368.0
#           1977     64.0   23122708.0
#           1982     66.0   25211637.0
#           1987     68.0   27310159.0
#           1992     70.0   29570964.0
#           1997     71.0   31876016.0
#           2002     72.0   33990910.0
#           2007     74.0   35954847.0
# ...

# %%
df.groupby(['continent','year'])[['lifeExp','pop']].mean().reset_index()
# Out:
#    continent  year    lifeExp           pop
# 0     Africa  1952  39.135500  4.570010e+06
# 1     Africa  1957  41.266346  5.093033e+06
# 2     Africa  1962  43.319442  5.702247e+06
# 3     Africa  1967  45.334538  6.447875e+06
# 4     Africa  1972  47.450942  7.305376e+06
# 5     Africa  1977  49.580423  8.328097e+06
# 6     Africa  1982  51.592865  9.602857e+06
# 7     Africa  1987  53.344788  1.105450e+07
# 8     Africa  1992  53.629577  1.267464e+07
# 9     Africa  1997  53.598269  1.430448e+07
# 10    Africa  2002  53.325231  1.603315e+07
# 11    Africa  2007  54.806038  1.787576e+07
# 12  Americas  1952  53.279840  1.380610e+07
# 13  Americas  1957  55.960280  1.547816e+07
# 14  Americas  1962  58.398760  1.733081e+07
# 15  Americas  1967  60.410920  1.922986e+07
# 16  Americas  1972  62.394920  2.117537e+07
# 17  Americas  1977  64.391560  2.312271e+07
# 18  Americas  1982  66.228840  2.521164e+07
# 19  Americas  1987  68.090720  2.731016e+07
# ...

# %%
r1 = df.groupby(['continent','year'])[['lifeExp','pop']].mean()
r1.loc['Asia', 1997]
# Out:
# lifeExp    6.802052e+01
# pop        1.025238e+08
# Name: (Asia, 1997), dtype: float64

# %%
r2 = df.groupby(['continent','year'])[['lifeExp','pop']].mean().reset_index()
r2.loc[r2['continent']=='Asia']
r2.loc[(r2['continent']=='Asia') & (r2['year']==1997)]
# Out:
#    continent  year    lifeExp           pop
# 33      Asia  1997  68.020515  1.025238e+08

# %%
df2
# Out:
#         price   msrp
# apple    3.50   4.99
# milk     2.68   3.99
# bread    1.41   1.99
# beer     9.90  19.99
# diaper  18.21  29.99

# %%
df2.T
# Out:
#        apple  milk  bread   beer  diaper
# price   3.50  2.68   1.41   9.90   18.21
# msrp    4.99  3.99   1.99  19.99   29.99

# %%
df2['price'].mean()
df2['price'].min()
df2['price'].max()
df2['price'].median()
# Out:
# 3.5

# %%
df2['price'].sort_values()
# Out:
# bread      1.41
# milk       2.68
# apple      3.50
# beer       9.90
# diaper    18.21
# Name: price, dtype: float64

# %%
df2.describe()
# Out:
#            price       msrp
# count   5.000000   5.000000
# mean    7.140000  12.190000
# std     7.002439  12.255611
# min     1.410000   1.990000
# 25%     2.680000   3.990000
# 50%     3.500000   4.990000
# 75%     9.900000  19.990000
# max    18.210000  29.990000

# %%
prices = df2['price']
prices[prices<prices.mean()] 

df2[(df2['price']>df2['price'].mean()) | (df2['msrp']>20)]
# Out:
#         price   msrp
# beer     9.90  19.99
# diaper  18.21  29.99

# %%
str(df2['msrp'])
df2['msrp'].astype('str')
# Out:
# apple      4.99
# milk       3.99
# bread      1.99
# beer      19.99
# diaper    29.99
# Name: msrp, dtype: object

# %%
df2 = pd.DataFrame({'price': [3.50, 2.68, 1.41, 9.90, 18.21],
                   'msrp': [4.99, 3.99, 1.99, 19.99, 29.99],
                   'prodcat': ['fruit', 'dairy', 'bakery', 'alcohol', 'baby'],
                   'discount': ['10', '10', '10', '5', '5']},
                  index=['apple', 'milk', 'bread', 'beer', 'diaper'])

# %%
df2['discount'].astype('float')
# Out:
# apple     10.0
# milk      10.0
# bread     10.0
# beer       5.0
# diaper     5.0
# Name: discount, dtype: float64

# %%
df2.loc['bread','discount'] = 'none'
df2
# Out:
#         price   msrp  prodcat discount
# apple    3.50   4.99    fruit       10
# milk     2.68   3.99    dairy       10
# bread    1.41   1.99   bakery     none
# beer     9.90  19.99  alcohol        5
# diaper  18.21  29.99     baby        5

# %%
df2['discount'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [85], line 1
# ----> 1 df2['discount'].astype('float')
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py:5546, in NDFrame.astype(self, dtype, copy, errors)
#    5539     results = [
#    5540         self.iloc[:, i].astype(dtype, copy=copy)
#    5541         for i in range(len(self.columns))
#    5542     ]
#    5544 else:
#    5545     # else, only a single dtype is given
# -> 5546     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547     return self._constructor(new_data).__finalize__(self, method="astype")
#    5549 # GH 33113: handle empty frame or series
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\managers.py:595, in BlockManager.astype(self, dtype, copy, errors)
#     592 def astype(
# ...

# %%
#pd.to_numeric(df2['discount'], errors='ignore')
#pd.to_numeric(df2['discount'], errors='raise')
pd.to_numeric(df2['discount'], errors='coerce')
# Out:
# apple     10.0
# milk      10.0
# bread      NaN
# beer       5.0
# diaper     5.0
# Name: discount, dtype: float64

# %%
df = pd.read_csv("datasets/scientists.csv", sep=',')

df['born_dt'] = pd.to_datetime(df['Born'], format='%Y-%m-%d')
print('age today in days')
print(pd.to_datetime('2022-10-25', format='%Y-%m-%d') - df['born_dt'])
# Out:
# age today in days
# 0   37347 days
# 1   53459 days
# 2   73945 days
# 3   56600 days
# 4   42155 days
# 5   76560 days
# 6   40301 days
# 7   89662 days
# Name: born_dt, dtype: timedelta64[ns]
